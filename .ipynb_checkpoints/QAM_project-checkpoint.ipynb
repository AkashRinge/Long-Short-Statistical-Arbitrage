# %%
import requests
import pandas as pd
import numpy as np
import yfinance as yf
import io
import seaborn as sns; sns.set_theme(color_codes=True)
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.api as sm
from statsmodels.tsa.ar_model import AutoReg

# %% [markdown]
# # Procuring Data
# First we need to extract the tickers for SnP-500

# %%
# The first input contains the list of tickers
url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"

# Disable SSL verification warnings for Wikipedia
requests.packages.urllib3.disable_warnings(requests.packages.urllib3.exceptions.InsecureRequestWarning)

# Fetch the content without verifying the SSL certificate
response = requests.get(url, verify=False)

# Read the content as a CSV file with pandas
ticker_df = pd.read_html(io.StringIO(response.text))[0]
ticker_df
# Out:
#     Symbol              Security             GICS Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4      ACN             Accenture  Information Technology
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  Date added  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
# 1                     Building Products     Milwaukee, Wisconsin  2017-07-26
# 2                 Health Care Equipment  North Chicago, Illinois  1957-03-04
# 3                       Pharmaceuticals  North Chicago, Illinois  2012-12-31
# 4        IT Consulting & Other Services          Dublin, Ireland  2011-07-06
# ..                                  ...                      ...         ...
# 498                         Restaurants     Louisville, Kentucky  1997-10-06
# 499  Electronic Equipment & Instruments   Lincolnshire, Illinois  2019-12-23
# 500               Health Care Equipment          Warsaw, Indiana  2001-08-07
# 501                      Regional Banks     Salt Lake City, Utah  2001-06-22
# 502                     Pharmaceuticals   Parsippany, New Jersey  2013-06-21
#
#          CIK      Founded
# 0      66740         1902
# 1      91142         1916
# 2       1800         1888
# 3    1551152  2013 (1888)
# 4    1467373         1989
# ..       ...          ...
# 498  1041061         1997
# 499   877212         1969
# 500  1136869         1927
# 501   109380         1873
# 502  1555280         1952
#
# [503 rows x 8 columns]

# %% [markdown]
# #### We will rely on Yahoo Finance API for our data
# However YFinance is not always a reliable data measure since
# * Unofficial / not necessarily maintained
# * Can get you rate limited/blacklisted

# %% [markdown]
# Lets verify if the intraday stock data is correctly downloading

# %%
data = yf.download(tickers=['MMM', 'ACN'], start="2022-01-01", end="2022-12-31", interval='60m')
data
# Out:
# [*********************100%***********************]  2 of 2 completed
#                             Adj Close                   Close              \
#                                   ACN         MMM         ACN         MMM
# Datetime
# 2022-01-03 09:30:00-05:00  408.825012  177.214996  408.825012  177.214996
# 2022-01-03 10:30:00-05:00  407.040009  176.820007  407.040009  176.820007
# 2022-01-03 11:30:00-05:00  407.329987  176.529999  407.329987  176.529999
# 2022-01-03 12:30:00-05:00  406.739990  176.440002  406.739990  176.440002
# 2022-01-03 13:30:00-05:00  407.864990  177.089996  407.864990  177.089996
#
# [1755 rows x 6 columns]

# %% [markdown]
# # Lets find annualized intraday volatility of each stock

# %%
for ticker, df in stock_data.items():
    temp_df = df.copy().dropna()
    
    # calculate daily volatility
    temp_df["Returns"] = temp_df["Adj Close"]/temp_df["Adj Close"].shift(1)
    daily_volatility = temp_df['Returns'].groupby(pd.Grouper(freq='D')).std()

    # Convert the annualized_intraday_volatility series to a DataFrame
    daily_volatility_df = daily_volatility.to_frame(name='Daily Vol')

    # Perform an asof merge with left_index=True and right_index=True
    temp_df = pd.merge_asof(temp_df, daily_volatility_df, left_index=True, right_index=True, direction='forward')
    temp_df.fillna(method='ffill', inplace=True) # forward fill
    
    stock_data[ticker] = temp_df

# %% [markdown]
# ### For our trading model, we will chose the top 50 stocks with most intraday volatility

# %%
# Averaging intraday volatilites for all stocks
mean_vol = {ticker: df["Daily Vol"].mean() for ticker, df in stock_data.items()}

# Reverse sorting based on volatilities
mean_vol = sorted(mean_vol.items(), key=lambda x: x[1], reverse=True)
column_names = ['Ticker', 'Daily Vol']
trade_deck = pd.DataFrame(data=mean_vol[:50], columns=column_names)
trade_deck[:5]
# Out:
#   Ticker  Daily Vol
# 0   ETSY   0.015262
# 1    CCL   0.015135
# 2   ENPH   0.015000
# 3   NCLH   0.014827
# 4   MRNA   0.014466

# %% [markdown]
# ### We also need SnP 500 weights for these stocks. Since this data is not available on any free API I will be using the crsp database provided by my university to calculate approximate daily weights for each of the top 50 volatile stock in SPX using market cap weighting

# %%
df_snp = pd.read_csv("snp500_2022.csv")
df_snp["MARKETCAP"] = df_snp["PRC"] * df_snp["VOL"]
df_snp
# Out:
#        PERMNO        date TICKER        PRC        VOL   SHROUT    OPENPRC  \
# 0       13210  2022-01-03   EPAM  642.20001     433216    56720  670.32001
# 1       13210  2022-01-04   EPAM  618.71002     509128    56720  641.21002
# 2       13210  2022-01-05   EPAM  587.79999     581163    56720  605.84998
# 3       13210  2022-01-06   EPAM  579.04999     616214    56720  579.45001
# 4       13210  2022-01-07   EPAM  556.67999     471129    56720  578.92999
# ...       ...         ...    ...        ...        ...      ...        ...
# 12728   93436  2022-12-23   TSLA  123.15000  166917212  3157752  126.37000
# 12729   93436  2022-12-27   TSLA  109.10000  208446557  3157752  117.49500
# 12730   93436  2022-12-28   TSLA  112.71000  220818648  3157752  110.35000
# 12731   93436  2022-12-29   TSLA  121.82000  221592714  3157752  120.38500
# 12732   93436  2022-12-30   TSLA  123.18000  157632606  3157752  119.95000
#
#           MARKETCAP
# 0      2.782113e+08
# 1      3.150026e+08
# 2      3.416076e+08
# 3      3.568187e+08
# 4      2.622681e+08
# ...             ...
# 12728  2.055585e+10
# 12729  2.274152e+10
# 12730  2.488847e+10
# 12731  2.699442e+10
# 12732  1.941718e+10
#
# [12733 rows x 8 columns]

# %%
# group by date and find individual wts approximate by individual MARKETCAP/ total MARKETCAP
group = df_snp.groupby("date")
df_snp["SNPWT"] = group["MARKETCAP"].transform(lambda x: x/x.sum())
df_snp
# Out:
#        PERMNO        date TICKER        PRC        VOL   SHROUT    OPENPRC  \
# 0       13210  2022-01-03   EPAM  642.20001     433216    56720  670.32001
# 1       13210  2022-01-04   EPAM  618.71002     509128    56720  641.21002
# 2       13210  2022-01-05   EPAM  587.79999     581163    56720  605.84998
# 3       13210  2022-01-06   EPAM  579.04999     616214    56720  579.45001
# 4       13210  2022-01-07   EPAM  556.67999     471129    56720  578.92999
# ...       ...         ...    ...        ...        ...      ...        ...
# 12728   93436  2022-12-23   TSLA  123.15000  166917212  3157752  126.37000
# 12729   93436  2022-12-27   TSLA  109.10000  208446557  3157752  117.49500
# 12730   93436  2022-12-28   TSLA  112.71000  220818648  3157752  110.35000
# 12731   93436  2022-12-29   TSLA  121.82000  221592714  3157752  120.38500
# 12732   93436  2022-12-30   TSLA  123.18000  157632606  3157752  119.95000
#
#           MARKETCAP     SNPWT
# 0      2.782113e+08  0.003072
# 1      3.150026e+08  0.003188
# 2      3.416076e+08  0.004021
# 3      3.568187e+08  0.004021
# 4      2.622681e+08  0.003474
# ...             ...       ...
# 12728  2.055585e+10  0.470628
# 12729  2.274152e+10  0.467241
# 12730  2.488847e+10  0.516440
# 12731  2.699442e+10  0.515800
# 12732  1.941718e+10  0.471974
#
# [12733 rows x 9 columns]

# %% [markdown]
# # Pattern Analysis

# %%
# Lets look at some plots to analyze what kind of data does the volatilities exhibit
# Get 5 tickers -> lets take 1, 10, 20, 30 tickers 
ats = [trade_deck.iloc[i]["Ticker"] for i in [1,18,32,45]]

fig, axes = plt.subplots(2, 2, figsize=(14, 10))
row, col = 0,0
for ticker in ats:
    if ticker in stock_data:
        group = stock_data[ticker]
        x_values = mdates.date2num(group.index)
        scatter_kws = {'alpha':0.6}  # set marker color
        line_kws = {'color': "black"}
        sns.regplot(ax=axes[row, col], data=group, x=x_values, y='Daily Vol', scatter_kws=scatter_kws, line_kws=line_kws, ci=100)
        col = col+1
        if col == 2:
            row = row+1
            col=0

# %% [markdown]
# Most of the data points are scattered with heavy noise and also have a number of outliers.

# %% [markdown]
# ### Volatility Partial Autocorrelations

# %%
fig, axs = plt.subplots(nrows=5, ncols=3, figsize=(30, 20))
axs = axs.ravel()
i=0
ats = trade_deck["Ticker"].sample(n=15).values
for ticker in ats:
    #plot_acf(stock_data[ticker]["Intraday Vol"])
    groupby_obj = stock_data[ticker].groupby(pd.Grouper(freq='D'))
    y = groupby_obj.first()["Daily Vol"]
    y.fillna(y.mean(), inplace=True)
    plot_pacf(y, ax=axs[i])
    i+=1

# %% [markdown]
# The first lag is kind of significant which means yesterday's volatility is our best guess for the forecast of today's volatility for most of these volatilies. A way to model intraday volatility could be ARCH(1).

# %% [markdown]
# ### Stock price partial autocorrelation

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))
ats = trade_deck["Ticker"].sample(n=4).values
row, col = 0, 0
for ticker in ats:
    #plot_acf(stock_data[ticker]["Intraday Vol"])
    groupby_obj = stock_data[ticker].groupby(pd.Grouper(freq='D'))
    y = groupby_obj["Adj Close"].median()
    y.fillna(y.mean(), inplace=True)
    plot_pacf(y, ax=axs[row, col])
    col = col+1
    if col == 2:
        row = row+1
        col=0

# %% [markdown]
# ##### Stock price differenced autocorrelation

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))
ats = trade_deck["Ticker"].sample(n=4).values
row, col = 0, 0
for ticker in ats:
    #plot_acf(stock_data[ticker]["Intraday Vol"])
    groupby_obj = stock_data[ticker].groupby(pd.Grouper(freq='D'))
    y = groupby_obj["Adj Close"].median()
    y.fillna(y.mean(), inplace=True)
    y = y
    y.fillna(y.mean(), inplace=True)
    plot_acf(y, ax=axs[row, col])
    col = col+1
    if col == 2:
        row = row+1
        col=0

# %% [markdown]
# The daily stock prices seem to be difficult to model using time series.

# %% [markdown]
# ### Frequency distribution of returns

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))
row, col = 0, 0
for ticker in ats:
    axs[row, col].hist(stock_data[ticker]["Returns"], bins=100, density=True, alpha=0.5, color='blue')
    col = col+1
    if col == 2:
        row = row+1
        col=0

# %% [markdown]
# The return series resemble a normal distribution to a good extent.

# %% [markdown]
#  # Trading strategy

# %% [markdown]
# ### 1. We will use a pairs trading strategy for long short abitrage. For each high volatility stock we identify another one with highest correlation to its returns and assign them as a pair. If no such pair found we assign a pair randomly

# %%
pairs = []
for stock in trade_deck["Ticker"]:
    pair = ''
    prev_c = 0
    for stock2 in trade_deck["Ticker"]:
        c = stock_data[stock]["Returns"].corr(stock_data[stock2]["Returns"])
        if stock2 != stock and c > 0.5 and c > prev_c:
                prev_c = c
                pair = stock2
    pairs.append(pair)
    
trade_deck["Pair"] = pairs
trade_deck.loc[trade_deck["Pair"]=="", "Pair"] = trade_deck["Ticker"].sample(n=1).values[0]
trade_deck
# Out:
#    Ticker  Daily Vol  Pair
# 0    ETSY   0.015262  CDAY
# 1     CCL   0.015135  NCLH
# 2    ENPH   0.015000  SEDG
# 3    NCLH   0.014827   CCL
# 4    MRNA   0.014466   KMX
# 5    SEDG   0.014423  ENPH
# 6     CZR   0.013617  NCLH
# 7    GNRC   0.013405  ENPH
# 8    EPAM   0.013342  MPWR
# 9     WBD   0.013320  PARA
# 10    RCL   0.013190  NCLH
# 11   NVDA   0.012945   AMD
# 12    APA   0.012703   MRO
# 13   MTCH   0.012646   CZR
# 14    EQT   0.012605   APA
# 15   TSLA   0.012566  NVDA
# 16    AMD   0.012466  NVDA
# 17   MPWR   0.012394  NVDA
# 18   ALGN   0.012321  CDAY
# 19     ON   0.012102  AMAT
# 20   NFLX   0.012043  PYPL
# 21    MOS   0.011876    CF
# 22   WYNN   0.011589   LVS
# 23    DVN   0.011528   MRO
# 24    NOW   0.011470  PAYC
# 25    FCX   0.011453   APA
# 26   PARA   0.011449   WBD
# 27   EXPE   0.011442   RCL
# 28   CDAY   0.011431  PAYC
# 29    ALB   0.011408  AMAT
# 30    OXY   0.011404   MRO
# 31     CF   0.011396   MOS
# 32   DISH   0.011360   CZR
# 33   BBWI   0.011291   CZR
# 34    AAL   0.011291   UAL
# 35    MRO   0.011231   DVN
# 36    UAL   0.011184   AAL
# 37    HAL   0.011159   MRO
# 38   DXCM   0.010927  ILMN
# 39   FSLR   0.010906  ENPH
# 40   PYPL   0.010860  PAYC
# 41     MU   0.010844  AMAT
# 42    LVS   0.010842  WYNN
# 43   LRCX   0.010813  AMAT
# 44   PODD   0.010801  ILMN
# 45   ILMN   0.010792  CDAY
# 46    KMX   0.010668   CZR
# 47   FANG   0.010646   MRO
# 48   PAYC   0.010585  CDAY
# 49   AMAT   0.010560  LRCX

# %% [markdown]
# ### 2. Since the 1st lag is the most significant we can use Exponential Moving Average (EMA) model to model volatilites with a weight of lets say 0.9

# %%
def ema_forecast(train_vol, alpha, horizon):
    ema = train_vol.ewm(alpha=alpha).mean()
    return ema.iloc[-1] * np.ones(horizon)

fig, axs = plt.subplots(5, 10, figsize=(30,20))
row, col = 0, 0
test1 = {}
for stock in trade_deck["Ticker"]:
    
    # For June
    train = stock_data[stock].resample('D').mean()
    train.fillna(train.mean(), inplace=True)
    test = train.loc['2022-06'].copy()
    test = test[["Daily Vol"]]

    alpha = 0.9
    forecasts = []

    for i in test.index:
        daily_vol = train.loc[(train.index < i)]["Daily Vol"]
        forecast = ema_forecast(daily_vol, alpha, 1)
        forecasts.append(forecast[0])

    test["Forecasts"] = forecasts
    test1[stock] = test
    axs[row, col].plot(test["Forecasts"], label="Forecasts")
    axs[row, col].plot(test["Daily Vol"], label="Actual")
    col += 1
    if col == 10:
        row += 1
        col = 0

# %% [markdown]
# The forecasts and actual volatility plots are above for the 50 stocks in contention

# %%
test2 = {}
for stock in trade_deck["Ticker"]:
    
    # For Sept
    train = stock_data[stock].resample('D').mean()
    train.fillna(train.mean(), inplace=True)
    test = train.loc['2022-09'].copy()
    test = test[["Daily Vol"]]

    alpha = 0.9
    forecasts = []

    for i in test.index:
        daily_vol = train.loc[(train.index < i)]["Daily Vol"]
        forecast = ema_forecast(daily_vol, alpha, 1)
        forecasts.append(forecast[0])

    test["Forecasts"] = forecasts
    test2[stock] = test

# %% [markdown]
# # Signal Generation

# %% [markdown]
# ### 3. We will use HMM model to generate BUY, SELL and HOLD signals.
# After training the model, we use it to generate hidden states for each hour in the dataset. Based on the hidden states, we generate buy, sell, and do nothing signals. We will calculate the returns and some portfolio metrics

# %%
#1.Identify undervalued and overvalued stocks based on trade volume, opening price, 20 day moving average
data = yf.download(tickers=trade_deck["Ticker"].tolist(), start="2021-01-01", end="2022-09-30", interval='1d')
data.fillna(data.mean(), inplace=True)

# Store each stock's data in a separate DataFrame
temp = {}
for ticker in trade_deck["Ticker"]:
    temp[ticker] = data.xs(ticker, level=1, axis=1)
data = temp

window = 20
for ticker in trade_deck["Ticker"]:
    temp = data[ticker].copy()
    temp["Rolling Price"] = temp["Adj Close"].rolling(window=window).mean()
    temp["Rolling Price"].fillna(temp["Rolling Price"].mean(), inplace=True)
    temp = temp.drop(['Open', 'Close', 'High', 'Low'], axis=1)
    temp["Market Cap"] = temp["Adj Close"] * temp["Volume"]
    data[ticker] = temp

split = int(len(data[ticker]) * 0.8)
model_predict(data[ticker][:split])

#train = data[:int(0.8*len(data))]
#test = data[int(0.8*len(data)):]
# Out:
# [*********************100%***********************]  50 of 50 completed
# Epoch 1/100
# 11/11 - 5s - loss: 0.2441 - 5s/epoch - 446ms/step
# Epoch 2/100
# 11/11 - 0s - loss: 0.1653 - 62ms/epoch - 6ms/step
# Epoch 3/100
# 11/11 - 0s - loss: 0.1020 - 61ms/epoch - 6ms/step
# Epoch 4/100
# 11/11 - 0s - loss: 0.0560 - 80ms/epoch - 7ms/step
# Epoch 5/100
# 11/11 - 0s - loss: 0.0266 - 59ms/epoch - 5ms/step
# Epoch 6/100
# 11/11 - 0s - loss: 0.0133 - 63ms/epoch - 6ms/step
# Epoch 7/100
# 11/11 - 0s - loss: 0.0103 - 64ms/epoch - 6ms/step
# Epoch 8/100
# 11/11 - 0s - loss: 0.0099 - 61ms/epoch - 6ms/step
# Epoch 9/100
# 11/11 - 0s - loss: 0.0096 - 68ms/epoch - 6ms/step
# Epoch 10/100
# 11/11 - 0s - loss: 0.0091 - 71ms/epoch - 6ms/step
# Epoch 11/100
# 11/11 - 0s - loss: 0.0088 - 54ms/epoch - 5ms/step
# Epoch 12/100
# 11/11 - 0s - loss: 0.0085 - 60ms/epoch - 5ms/step
# Epoch 13/100
# 11/11 - 0s - loss: 0.0082 - 55ms/epoch - 5ms/step
# Epoch 14/100
# 11/11 - 0s - loss: 0.0078 - 64ms/epoch - 6ms/step
# Epoch 15/100
# 11/11 - 0s - loss: 0.0075 - 69ms/epoch - 6ms/step
# Epoch 16/100
# 11/11 - 0s - loss: 0.0073 - 59ms/epoch - 5ms/step
# Epoch 17/100
# 11/11 - 0s - loss: 0.0070 - 60ms/epoch - 5ms/step
# Epoch 18/100
# 11/11 - 0s - loss: 0.0067 - 71ms/epoch - 6ms/step
# Epoch 19/100
# 11/11 - 0s - loss: 0.0065 - 65ms/epoch - 6ms/step
# Epoch 20/100
# 11/11 - 0s - loss: 0.0062 - 74ms/epoch - 7ms/step
# Epoch 21/100
# 11/11 - 0s - loss: 0.0060 - 74ms/epoch - 7ms/step
# Epoch 22/100
# 11/11 - 0s - loss: 0.0058 - 79ms/epoch - 7ms/step
# Epoch 23/100
# 11/11 - 0s - loss: 0.0056 - 78ms/epoch - 7ms/step
# Epoch 24/100
# 11/11 - 0s - loss: 0.0054 - 67ms/epoch - 6ms/step
# Epoch 25/100
# 11/11 - 0s - loss: 0.0052 - 83ms/epoch - 8ms/step
# Epoch 26/100
# 11/11 - 0s - loss: 0.0051 - 77ms/epoch - 7ms/step
# Epoch 27/100
# 11/11 - 0s - loss: 0.0049 - 70ms/epoch - 6ms/step
# Epoch 28/100
# 11/11 - 0s - loss: 0.0048 - 72ms/epoch - 7ms/step
# Epoch 29/100
# 11/11 - 0s - loss: 0.0046 - 70ms/epoch - 6ms/step
# Epoch 30/100
# 11/11 - 0s - loss: 0.0045 - 62ms/epoch - 6ms/step
# Epoch 31/100
# 11/11 - 0s - loss: 0.0044 - 71ms/epoch - 6ms/step
# Epoch 32/100
# 11/11 - 0s - loss: 0.0043 - 71ms/epoch - 6ms/step
# Epoch 33/100
# 11/11 - 0s - loss: 0.0042 - 65ms/epoch - 6ms/step
# Epoch 34/100
# 11/11 - 0s - loss: 0.0041 - 63ms/epoch - 6ms/step
# Epoch 35/100
# 11/11 - 0s - loss: 0.0040 - 75ms/epoch - 7ms/step
# Epoch 36/100
# 11/11 - 0s - loss: 0.0039 - 77ms/epoch - 7ms/step
# Epoch 37/100
# 11/11 - 0s - loss: 0.0039 - 57ms/epoch - 5ms/step
# Epoch 38/100
# 11/11 - 0s - loss: 0.0038 - 61ms/epoch - 6ms/step
# Epoch 39/100
# 11/11 - 0s - loss: 0.0038 - 67ms/epoch - 6ms/step
# Epoch 40/100
# 11/11 - 0s - loss: 0.0037 - 74ms/epoch - 7ms/step
# Epoch 41/100
# 11/11 - 0s - loss: 0.0036 - 63ms/epoch - 6ms/step
# Epoch 42/100
# 11/11 - 0s - loss: 0.0036 - 59ms/epoch - 5ms/step
# Epoch 43/100
# 11/11 - 0s - loss: 0.0035 - 66ms/epoch - 6ms/step
# Epoch 44/100
# 11/11 - 0s - loss: 0.0035 - 62ms/epoch - 6ms/step
# Epoch 45/100
# 11/11 - 0s - loss: 0.0034 - 72ms/epoch - 7ms/step
# Epoch 46/100
# 11/11 - 0s - loss: 0.0034 - 67ms/epoch - 6ms/step
# Epoch 47/100
# 11/11 - 0s - loss: 0.0033 - 65ms/epoch - 6ms/step
# Epoch 48/100
# 11/11 - 0s - loss: 0.0033 - 62ms/epoch - 6ms/step
# Epoch 49/100
# 11/11 - 0s - loss: 0.0032 - 69ms/epoch - 6ms/step
# Epoch 50/100
# 11/11 - 0s - loss: 0.0032 - 60ms/epoch - 5ms/step
# Epoch 51/100
# 11/11 - 0s - loss: 0.0031 - 59ms/epoch - 5ms/step
# Epoch 52/100
# 11/11 - 0s - loss: 0.0031 - 59ms/epoch - 5ms/step
# Epoch 53/100
# 11/11 - 0s - loss: 0.0030 - 62ms/epoch - 6ms/step
# Epoch 54/100
# 11/11 - 0s - loss: 0.0030 - 61ms/epoch - 6ms/step
# Epoch 55/100
# 11/11 - 0s - loss: 0.0030 - 70ms/epoch - 6ms/step
# Epoch 56/100
# 11/11 - 0s - loss: 0.0029 - 69ms/epoch - 6ms/step
# Epoch 57/100
# 11/11 - 0s - loss: 0.0029 - 61ms/epoch - 6ms/step
# Epoch 58/100
# 11/11 - 0s - loss: 0.0028 - 66ms/epoch - 6ms/step
# Epoch 59/100
# 11/11 - 0s - loss: 0.0028 - 52ms/epoch - 5ms/step
# Epoch 60/100
# 11/11 - 0s - loss: 0.0028 - 59ms/epoch - 5ms/step
# Epoch 61/100
# 11/11 - 0s - loss: 0.0028 - 62ms/epoch - 6ms/step
# Epoch 62/100
# 11/11 - 0s - loss: 0.0027 - 61ms/epoch - 6ms/step
# Epoch 63/100
# 11/11 - 0s - loss: 0.0027 - 61ms/epoch - 6ms/step
# Epoch 64/100
# 11/11 - 0s - loss: 0.0027 - 66ms/epoch - 6ms/step
# Epoch 65/100
# 11/11 - 0s - loss: 0.0027 - 71ms/epoch - 6ms/step
# Epoch 66/100
# 11/11 - 0s - loss: 0.0026 - 80ms/epoch - 7ms/step
# Epoch 67/100
# 11/11 - 0s - loss: 0.0026 - 58ms/epoch - 5ms/step
# Epoch 68/100
# 11/11 - 0s - loss: 0.0026 - 62ms/epoch - 6ms/step
# Epoch 69/100
# 11/11 - 0s - loss: 0.0025 - 69ms/epoch - 6ms/step
# Epoch 70/100
# 11/11 - 0s - loss: 0.0025 - 73ms/epoch - 7ms/step
# Epoch 71/100
# 11/11 - 0s - loss: 0.0025 - 62ms/epoch - 6ms/step
# Epoch 72/100
# 11/11 - 0s - loss: 0.0025 - 74ms/epoch - 7ms/step
# Epoch 73/100
# 11/11 - 0s - loss: 0.0024 - 63ms/epoch - 6ms/step
# Epoch 74/100
# 11/11 - 0s - loss: 0.0024 - 66ms/epoch - 6ms/step
# Epoch 75/100
# 11/11 - 0s - loss: 0.0024 - 70ms/epoch - 6ms/step
# Epoch 76/100
# 11/11 - 0s - loss: 0.0024 - 68ms/epoch - 6ms/step
# Epoch 77/100
# 11/11 - 0s - loss: 0.0024 - 69ms/epoch - 6ms/step
# Epoch 78/100
# 11/11 - 0s - loss: 0.0024 - 71ms/epoch - 6ms/step
# Epoch 79/100
# 11/11 - 0s - loss: 0.0023 - 56ms/epoch - 5ms/step
# Epoch 80/100
# 11/11 - 0s - loss: 0.0023 - 68ms/epoch - 6ms/step
# Epoch 81/100
# 11/11 - 0s - loss: 0.0023 - 64ms/epoch - 6ms/step
# Epoch 82/100
# 11/11 - 0s - loss: 0.0023 - 73ms/epoch - 7ms/step
# Epoch 83/100
# 11/11 - 0s - loss: 0.0023 - 70ms/epoch - 6ms/step
# Epoch 84/100
# 11/11 - 0s - loss: 0.0023 - 62ms/epoch - 6ms/step
# Epoch 85/100
# 11/11 - 0s - loss: 0.0023 - 58ms/epoch - 5ms/step
# Epoch 86/100
# 11/11 - 0s - loss: 0.0023 - 59ms/epoch - 5ms/step
# Epoch 87/100
# 11/11 - 0s - loss: 0.0022 - 65ms/epoch - 6ms/step
# Epoch 88/100
# 11/11 - 0s - loss: 0.0022 - 61ms/epoch - 6ms/step
# Epoch 89/100
# 11/11 - 0s - loss: 0.0022 - 70ms/epoch - 6ms/step
# Epoch 90/100
# 11/11 - 0s - loss: 0.0022 - 72ms/epoch - 7ms/step
# Epoch 91/100
# 11/11 - 0s - loss: 0.0022 - 76ms/epoch - 7ms/step
# Epoch 92/100
# 11/11 - 0s - loss: 0.0022 - 63ms/epoch - 6ms/step
# Epoch 93/100
# 11/11 - 0s - loss: 0.0022 - 70ms/epoch - 6ms/step
# Epoch 94/100
# 11/11 - 0s - loss: 0.0022 - 61ms/epoch - 6ms/step
# Epoch 95/100
# 11/11 - 0s - loss: 0.0022 - 72ms/epoch - 7ms/step
# Epoch 96/100
# 11/11 - 0s - loss: 0.0022 - 58ms/epoch - 5ms/step
# Epoch 97/100
# 11/11 - 0s - loss: 0.0022 - 59ms/epoch - 5ms/step
# Epoch 98/100
# 11/11 - 0s - loss: 0.0022 - 65ms/epoch - 6ms/step
# Epoch 99/100
# 11/11 - 0s - loss: 0.0022 - 65ms/epoch - 6ms/step
# Epoch 100/100
# 11/11 - 0s - loss: 0.0022 - 63ms/epoch - 6ms/step
# 1/1 [==============================] - 1s 1s/step
# array([107.14923187])

# %%
#2.If the forecasted price for the day is above 1x forecasted volatility we create a long position in the stock and a short position in its pair in ratio of their snp weights
#3.If the forecasted price for the day is 1x forecasted volatility below we create a short position in the stock and a long position in its pair in ratio of their snp weights
#4.We add the two positions to a position table and associate each other using a pair id.
#5.The target price for the trade is the forecasted price. We check for this price every hour. We square off both the position when the price moves above (below for short) the forecast
#6.We keep a stop loss of 3%. If our net pair trade value falls below 3% we square off the position and remove it from the position table
#7.Calculate returns of portfolio each hour and sum them

# %%
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense


# Preprocess the data
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back - 1):
        X.append(dataset[i:(i + look_back), :])
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

def model_predict(df):
    # Set look_back window
    look_back = 1

    # Load your data
    # df = ...

    # Select columns
    model_data = df[['Adj Close', 'Volume', 'Rolling Price']].values

    # Scale the data
    scaler = MinMaxScaler(feature_range=(0, 1))
    model_data = scaler.fit_transform(model_data)

    # Create dataset for the LSTM model
    X, Y = create_dataset(model_data, look_back)

    # Reshape the input to be [samples, time steps, features]
    X = np.reshape(X, (X.shape[0], X.shape[1], 3))

    # Create the LSTM model
    model = Sequential()
    model.add(LSTM(50, input_shape=(X.shape[1], X.shape[2])))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')

    # Train the model
    model.fit(X, Y, epochs=100, batch_size=32, verbose=0)

    # Make a prediction for the next day
    last_data = np.array([model_data[-1]])  # Take the last row of the dataset
    next_day_prediction = model.predict(last_data.reshape(1, 1, -1))

    # Invert scaling to get the original scale
    next_day_prediction = scaler.inverse_transform(np.hstack([next_day_prediction, last_data[:, 1:]]))[:, 0]

    return next_day_prediction

# %%
# Set look_back window
look_back = 1

# Load your data
# df = ...

# Select columns
model_data = data[ticker][['Adj Close', 'Volume', 'Rolling Price']].values

# Scale the data
scaler = MinMaxScaler(feature_range=(0, 1))
model_data = scaler.fit_transform(model_data)

# Create dataset for the LSTM model
X, Y = create_dataset(model_data, look_back)
X
# Out:
# array([[[0.10817608, 0.06365845, 0.14710339]],
#
#        [[0.10086965, 0.10231598, 0.14710339]],
#
#        [[0.09560907, 0.12500457, 0.14710339]],
#
#        ...,
#
#        [[0.48864513, 0.03182329, 0.57053022]],
#
#        [[0.480183  , 0.03013973, 0.56516777]],
#
#        [[0.48776757, 0.02650594, 0.56097857]]])

# %%
data[ticker][split:split+1]
# Out:
#                            Adj Close   Volume  Rolling Price    Market Cap
# Date
# 2022-05-25 00:00:00-04:00   107.7379  7378200     109.583179  7.949118e+08
